# %% [markdown]
# <a href="https://colab.research.google.com/github/MAboElFottouh/The-Sparks-Foundation/blob/main/task3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas  as pd #Data manipulation
import numpy as np #Data manipulation
import matplotlib.pyplot as plt # Visualization
import seaborn as sns #Visualization

# %%
data = pd.read_csv('/content/SampleSuperstore (1).csv')

# %%
print('\nNumber of rows and columns in the data set: ',data.shape)
#Lets look into top few rows and columns in the dataset
data.head()
# Out:
# Number of rows and columns in the data set:  (9994, 13)
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
print(data.groupby('Region').mean()['Profit'])
# Out:
# Region
# Central    17.092709
# East       32.135808
# South      28.857673
# West       33.849032
# Name: Profit, dtype: float64

# %%
data.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %% [markdown]
# # 1 **Country**
# # 4 **region**

# %%
data['Region'].value_counts()
# Out:
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: Region, dtype: int64

# %%
data['State'].value_counts()
# Out:
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# ...

# %%
data['City'].value_counts()
# Out:
# New York City      915
# Los Angeles        747
# Philadelphia       537
# San Francisco      510
# Seattle            428
#                   ...
# Glenview             1
# Missouri City        1
# Rochester Hills      1
# Palatine             1
# Manhattan            1
# Name: City, Length: 531, dtype: int64

# %% [markdown]
# # max and min porfit in all data and all region

# %%
data[data['Profit']==data['Profit'].max()]
# Out:
#            Ship Mode    Segment        Country       City    State  \
# 6826  Standard Class  Corporate  United States  Lafayette  Indiana
#
#       Postal Code   Region    Category Sub-Category     Sales  Quantity  \
# 6826        47905  Central  Technology      Copiers  17499.95         5
#
#       Discount    Profit
# 6826       0.0  8399.976

# %%
data[data['Profit']==data['Profit'].min()]
# Out:
#            Ship Mode   Segment        Country       City State  Postal Code  \
# 7772  Standard Class  Consumer  United States  Lancaster  Ohio        43130
#
#      Region    Category Sub-Category     Sales  Quantity  Discount    Profit
# 7772   East  Technology     Machines  4499.985         5       0.7 -6599.978

# %% [markdown]
# # :Region 1

# %% [markdown]
# #split data by region

# %%
dataE = data[data['Region']=='East']

# %%
dataE['City'].nunique()
# Out:
# 108

# %%
dataE[dataE['Profit']==dataE['Profit'].max()]
# Out:
#            Ship Mode   Segment        Country    City     State  Postal Code  \
# 4190  Standard Class  Consumer  United States  Newark  Delaware        19711
#
#      Region    Category Sub-Category     Sales  Quantity  Discount     Profit
# 4190   East  Technology      Copiers  10499.97         3       0.0  5039.9856

# %%
dataE[dataE['Profit']==dataE['Profit'].min()]
# Out:
#            Ship Mode   Segment        Country       City State  Postal Code  \
# 7772  Standard Class  Consumer  United States  Lancaster  Ohio        43130
#
#      Region    Category Sub-Category     Sales  Quantity  Discount    Profit
# 7772   East  Technology     Machines  4499.985         5       0.7 -6599.978

# %% [markdown]
# #Region 2

# %%
dataW = data[data['Region']=='West']

# %%
dataW['City'].nunique()
# Out:
# 169

# %%
dataW[dataW['Profit']==dataW['Profit'].max()]
# Out:
#         Ship Mode   Segment        Country     City       State  Postal Code  \
# 8153  First Class  Consumer  United States  Seattle  Washington        98115
#
#      Region    Category Sub-Category     Sales  Quantity  Discount     Profit
# 8153   West  Technology      Copiers  13999.96         4       0.0  6719.9808

# %%
dataW[dataW['Profit']==dataW['Profit'].min()]
# Out:
#            Ship Mode      Segment        Country        City     State  \
# 3011  Standard Class  Home Office  United States  Louisville  Colorado
#
#       Postal Code Region    Category Sub-Category     Sales  Quantity  \
# 3011        80027   West  Technology     Machines  2549.985         5
#
#       Discount   Profit
# 3011       0.7 -3399.98

# %% [markdown]
# #Region 3

# %%
dataS = data[data['Region']=='South']

# %%
dataS['City'].nunique()
# Out:
# 125

# %%
dataS[dataS['Profit']==dataS['Profit'].max()]
# Out:
#           Ship Mode   Segment        Country     City    State  Postal Code  \
# 509  Standard Class  Consumer  United States  Atlanta  Georgia        30318
#
#     Region         Category Sub-Category    Sales  Quantity  Discount  \
# 509  South  Office Supplies      Binders  6354.95         5       0.0
#
#        Profit
# 509  3177.475

# %%
dataS[dataS['Profit']==dataS['Profit'].min()]
# Out:
#     Ship Mode    Segment        Country        City           State  \
# 683  Same Day  Corporate  United States  Burlington  North Carolina
#
#      Postal Code Region    Category Sub-Category    Sales  Quantity  Discount  \
# 683        27217  South  Technology     Machines  7999.98         4       0.5
#
#         Profit
# 683 -3839.9904

# %% [markdown]
# #Region 4

# %%
dataC = data[data['Region']=='Central']

# %%
dataC['City'].nunique()
# Out:
# 181

# %%
dataC[dataC['Profit']==dataC['Profit'].max()]
# Out:
#            Ship Mode    Segment        Country       City    State  \
# 6826  Standard Class  Corporate  United States  Lafayette  Indiana
#
#       Postal Code   Region    Category Sub-Category     Sales  Quantity  \
# 6826        47905  Central  Technology      Copiers  17499.95         5
#
#       Discount    Profit
# 6826       0.0  8399.976

# %%
dataC[dataC['Profit']==dataC['Profit'].min()]
# Out:
#            Ship Mode   Segment        Country         City  State  \
# 9774  Standard Class  Consumer  United States  San Antonio  Texas
#
#       Postal Code   Region         Category Sub-Category     Sales  Quantity  \
# 9774        78207  Central  Office Supplies      Binders  2177.584         8
#
#       Discount     Profit
# 9774       0.8 -3701.8928
